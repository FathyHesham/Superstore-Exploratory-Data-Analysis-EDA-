# %% [markdown]
# <h1>
#   <b>
#     <p style="background-image: url(https://www.shutterstock.com/shutterstock/photos/2128959116/display_1500/stock-vector-abstract-waving-particle-technology-background-design-abstract-wave-moving-dots-flow-particles-hi-2128959116.jpg); font-family: Arial, sans-serif; font-size: 110%; color: #ff5733; text-align: center; border-radius: 10px 50px; padding: 30px; border: solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">
#       About Auther
#     </p>
#   </b>
# </h1>

# %% [markdown]
# <div style="background-color: #f5f5f5; border: 1px solid #ddd; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1); max-width: 600px; margin: 20px auto; padding: 20px; text-align: center; font-family: 'Times New Roman';">
#     <img src="https://i.postimg.cc/3rG5JBWp/Fathy.png" alt="Profile Picture" style="width: 120px; height: 120px; border-radius: 50%; border: 4px solid #00008B; margin-bottom: 15px;">
#     <h2 style="color: #00008B; font-weight: bold; margin-bottom: 10px;">Fathy Hesham Fathy El-Barbary</h2>
#     <p style="font-size: 16px; line-height: 1.6; color: #666; margin-bottom: 20px;">
#         Hi,<br>
#         Greetings!<br>
#         Welcome to my Notebook. I am a developer and engineer with a degree in Computer Science, specializing in machine learning and deep learning. I have extensive experience designing, training, and deploying models using TensorFlow, PyTorch, and Keras. Additionally, I am skilled in data preprocessing, feature selection, and data visualization. Passionate about solving complex problems with AI, I am dedicated to delivering high-quality solutions and staying current with advancements in this rapidly evolving field.
#     </p>
#     <a href="https://www.linkedin.com/in/fathy-hesham-fathy/" target="_blank" style="display: inline-block; background-color: #00008B; color: #ddd; text-decoration: none; padding: 20px 50px; border-radius: 5px;">Visit LinkedIn Profile</a>
# </div>

# %% [markdown]
# <h1>
#   <b>
#     <p style="background-image: url(https://media-cldnry.s-nbcnews.com/image/upload/t_nbcnews-fp-1024-512,f_auto,q_auto:best/newscms/2017_26/2053956/170627-better-grocery-store-main-se-539p.jpg); font-family: Arial, sans-serif; font-size: 110%; color: #ff5733; text-align: center; border-radius: 15px 50px; padding: 7px; border: solid 2px #09375b; box-shadow: 10px 10px 10px #042b4c">
#       🛍️💵 SuperStore ️🛒
#     </p>
#   </b>
# </h1>

# %% [markdown]
# <p style="font-family: 'Georgia', serif; font-size: 2.5rem; color: #2c3e50; text-align: center; margin: 0; text-shadow: 2px 2px 5px rgba(0, 0, 0, 0.2); background-color: #ecf0f1; padding: 25px; border-radius: 15px; border: 5px double #8e44ad; width: 95%;">
#   <span style="font-weight: bold; color: #e67e22; animation: pulse 1.5s infinite;">About</span> |
#   <span style="font-style: italic; color: #2980b9; animation: pulse 1.5s infinite;">Dataset</span>
# </p>

# %% [markdown]
# **Context**
# * With growing demands and cut-throat competition in the market, Superstore Giant is seeking your knowledge in understanding what works best for them. They would like to understand which products, regions, categories and customer segments they should target or avoid.
# * You can even take this a step further and try and build a Regression model to predict Sales or Profit.
# * Go crazy with the dataset, but also make sure to provide some business insights to improve.
#
# **Metadata (Order Data)**
#
# * **Row ID :** Unique identifier for each row in the table
# * **Order ID :** Unique identifier for each order
# * **Order Date :** Date the order was placed
# * **Ship Date :** Date the order was shipped
# * **Ship Mode :** Shipping method chosen by the customer
# * **Customer ID :** Unique identifier for each customer
# * **Customer Name :** Name of the customer
# * **Segment :** Customer segment (e.g., retail, wholesale)
# * **Country :** Customer’s country of residence
# * **City:** Customer’s city of residence
# * **State :** Customer’s state of residence
# * **Postal Code :** Customer’s postal code
# * **Region :** Customer’s region
# * **Product ID :** Unique identifier for each product
# * **Category :** Product category (e.g., electronics, clothing)
# * **Sub-Category :** Product subcategory
# * **Product Name :** Name of the product
# * **Sales :** Sales total for the product
# * **Quantity :** Number of units of the product sold
# * **Discount :** Discount applied to the product
# * **Profit :** Profit or loss incurred on the product
#
# **Metadata (Return Order)**
#
# * **Order ID :** Unique Order ID for each Customer.
# * **Returned :** Returned Orders.
#
# **Metadata (People)**
#
# * **Region :** Region where the Customer belongs.
# * **Name :** Name Responsible For Region.
#
# **Metadata (Shipping Cost Per Unit)**
#
# * **State :** State of residence of the Customer.
# * **Shipping Cost Per Unit**
#
# **Acknowledgements :** I do not own this data. I merely found it from the Tableau website. All credits to the original authors/creators. For educational purposes only.

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">📊 Importing Necessary Libraries
# </p>
#
# **Start by importing the necessary Python libraries. Common ones include `pandas`, `numpy`, and `matplotlib`. 📚**

# %%
import pandas as pd       # 🐼 Importing the pandas library for data manipulation and analysis
import numpy as np        # 🔢 Importing the numpy library for numerical operations
import matplotlib.pyplot as plt  # 📈 Importing the matplotlib library for plotting and visualizations

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">📦 Loading the Orders Dataset</p>
# **Load your dataset into a pandas DataFrame using functions like `pd.read_csv()` or `pd.read_excel()`. 📊**

# %% [markdown]
# ## Order Dataset

# %%
# 📂 Loading the Orders dataset from a CSV file, setting the first column as the index
orders_dataset = pd.read_csv("Dataset/Order.csv", index_col=0)

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">Understanding The Dataset 🧠</p>

# %% [markdown]
# #### 📋 Displaying a Random Sample of 5 Rows from the Orders Dataset

# %%
orders_dataset.sample(5)  # Displaying a random sample of 5 rows from the orders dataset
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 9438    CA-2017-107853   5/26/2017   503102017  Standard Class    CD-11920
# 2725    CA-2014-153479   10/4/2014   100802014  Standard Class    DF-13135
# 288     CA-2016-112697  12/18/2016  1202002016    Second Class    AH-10195
# 2785    CA-2016-116974   10/9/2016  1001502016  Standard Class    MP-17965
# 3669    CA-2014-129364   12/8/2014  1201302014  Standard Class    TB-21250
#
#          Customer Name    Segment                 Location       State  \
# Row ID
# 9438       Carlos Daly   Consumer  United States,Oceanside  California
# 2725    David Flashing   Consumer    United States,Vallejo  California
# 288        Alan Haines  Corporate    United States,Tamarac     Florida
# 2785     Michael Paige  Corporate       United States,Troy        Ohio
# 3669      Tim Brockman   Consumer      United States,Salem      Oregon
#
# ...

# %% [markdown]
# #### Getting the Shape of the Orders Dataset

# %%
print("Shape of the Orders Dataset:", orders_dataset.shape)  # Displaying the number of rows and columns in the orders dataset
# Out:
# Shape of the Orders Dataset: (9994, 19)

# %% [markdown]
# #### 🔍 Checking the Data Types of Each Column in the Orders Dataset

# %%
orders_dataset.dtypes  # Displaying the data types of each column in the orders dataset
# Out:
# Order ID          object
# Order Date        object
# Ship Date          int64
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Location          object
# State             object
# Postal Code        int64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %% [markdown]
# #### Retrieving Column Names of the Orders Dataset

# %%
orders_dataset.columns  # Displaying the column names of the orders dataset
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Location', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# #### Gathering Information about the Orders Dataset

# %%
orders_dataset.info()  # Displaying concise summary of the orders dataset, including data types and memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9994 entries, 1 to 9994
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       9994 non-null   object
#  1   Order Date     9994 non-null   object
#  2   Ship Date      9994 non-null   int64
#  3   Ship Mode      9994 non-null   object
#  4   Customer ID    9994 non-null   object
#  5   Customer Name  9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Location       9994 non-null   object
#  8   State          9994 non-null   object
#  9   Postal Code    9994 non-null   int64
#  10  Region         9994 non-null   object
#  11  Product ID     9994 non-null   object
#  12  Category       9994 non-null   object
#  13  Sub-Category   9994 non-null   object
#  14  Product Name   9994 non-null   object
#  15  Sales          9994 non-null   float64
#  16  Quantity       9994 non-null   int64
# ...

# %% [markdown]
# #### Descriptive Statistics for the Orders Dataset

# %%
orders_dataset.describe() ## include = "all" # Displaying descriptive statistics for all columns in the orders dataset
# Out:
#           Ship Date   Postal Code         Sales     Quantity     Discount  \
# count  9.994000e+03   9994.000000   9994.000000  9994.000000  9994.000000
# mean   5.755438e+08  55190.379428    229.858001     3.789574     0.156203
# std    4.223230e+08  32063.693350    623.245101     2.225110     0.206452
# min    1.010202e+07   1040.000000      0.444000     1.000000     0.000000
# 25%    1.105020e+08  23223.000000     17.280000     2.000000     0.000000
# 50%    6.015020e+08  56430.500000     54.490000     3.000000     0.200000
# 75%    1.001202e+09  90008.000000    209.940000     5.000000     0.200000
# max    1.203102e+09  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">Preproceeisng The Dataset</p>

# %% [markdown]
# #### Calculate Missing Values in the Orders Dataset

# %%
orders_dataset.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Location         0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %% [markdown]
# #### Check for Duplicate in Orders Dataset

# %%
# Count Duplicate Rows 
duplicate_count = orders_dataset.duplicated().sum()
print(f"There are {duplicate_count} duplicate rows found in 'orders_dataset'.")

# Remove Duplicate Rows
orders_dataset.drop_duplicates(inplace=True)

# Verify Removal of Duplicates
verified_duplicates = orders_dataset.duplicated().sum()
print(f"After dropping duplicates, there are {verified_duplicates} remaining duplicates (should be 0).")
# Out:
# There are 1 duplicate rows found in 'orders_dataset'.
# After dropping duplicates, there are 0 remaining duplicates (should be 0).

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">Issues Identified & Solved It 🛠️</p>

# %% [markdown]
# #### Issues Identified in the Dataset
#
# **Two issues identified:**
#
# * `1. Ship Date: Incorrect format and data type (currently string).`
# * `2. Location: Need to split the country into one column and the city into another column.`

# %%
# Displaying the First Few Rows of the Ship Date Column

orders_dataset["Ship Date"].head()  # Showing the first few rows of the Ship Date column in the orders dataset
# Out:
# Row ID
# 1    1101102016
# 2    1101102016
# 3     601602016
# 4    1001802015
# 5    1001802015
# Name: Ship Date, dtype: int64

# %% [markdown]
# #### 📅 Converting Integer Date Format to MM/DD/YYYY

# %%
'''
output ==> 6 0 28 0 2016 ==>  conver to ==> 6 / 28 / 2016

    * 6 => month
    * 28 => day
    * 2016 => year

    3 case : 
        - len 10 ==> 11 0 11 0 2016
        - len 9  ==> 6  0 14 0 2014
        - len 8  ==> 9  0  1 0 2014
'''

# Function to Convert Integer Date Format to MM/DD/YYYY
def convert_integer_date(date_int):
    date_str = str(date_int)  # Convert the integer date to a string
    year = date_str[-4:]      # Extract the year from the last four characters of the string
    if len(date_str) == 10:   # Check if the string length is 10
        month = date_str[:-8] # Extract the month from the string
        day = date_str[-7:-5] # Extract the day from the string
    elif len(date_str) == 9:  # Check if the string length is 9
        month = date_str[0]   # Extract the month from the first character of the string
        day = date_str[-7:-5] # Extract the day from the string
    elif len(date_str) == 8:  # Check if the string length is 8
        month = date_str[0]   # Extract the month from the first character of the string
        day = date_str[1:3]   # Extract the day from the second and third characters of the string
    else:
        raise ValueError("Invalid date format")  # Raise an error for invalid date formats
    formatted_date = f"{month}/{day}/{year}"  # Format the date as MM/DD/YYYY
    return formatted_date  # Return the formatted date

# Applying the Conversion Function to the 'Ship Date' Column
orders_dataset['Ship Date'] = orders_dataset['Ship Date'].apply(convert_integer_date)

# Displaying the First 5 Rows of the 'Ship Date' Column
orders_dataset["Ship Date"].head(5)
# Out:
# Row ID
# 1    11/11/2016
# 2    11/11/2016
# 3     6/16/2016
# 4    10/18/2015
# 5    10/18/2015
# Name: Ship Date, dtype: object

# %%
# Displaying the First 5 Rows of the Location Column
orders_dataset["Location"].head(5)  # Showing the first 5 rows of the Location column in the orders dataset
# Out:
# Row ID
# 1          United States,Henderson
# 2          United States,Henderson
# 3        United States,Los Angeles
# 4    United States,Fort Lauderdale
# 5    United States,Fort Lauderdale
# Name: Location, dtype: object

# %% [markdown]
# #### 🌍🏙️ Splitting the 'Location' Column into 'Country' and 'City'

# %%
# Splitting the 'Location' column into 'Country' and 'City' columns:
# Using str.split() with expand=True splits the 'Location' column by commas,
# creating two new columns 'Country' and 'City' in the orders_dataset DataFrame.
orders_dataset[['Country', 'City']] = orders_dataset['Location'].str.split(',', expand=True)

# Reordering the columns to place 'Country' and 'City' after 'Location':
# Convert the column names to a list and find the index of 'Location'.
columns = list(orders_dataset.columns)
location_idx = columns.index('Location')

# Define the new order of columns by placing 'Country' and 'City' after 'Location'.
new_columns_order = columns[:location_idx + 1] + ['Country', 'City'] + columns[location_idx + 1:-2]

# Apply the new column order to the orders_dataset DataFrame:
# Update orders_dataset with the new column order to reflect the split and reordering.
orders_dataset = orders_dataset[new_columns_order]

# Drop the original 'Location' column if it's no longer needed:
# Remove the 'Location' column from orders_dataset since it's been split into 'Country' and 'City'.
orders_dataset = orders_dataset.drop(columns=['Location'])

# Print the updated DataFrame to verify the changes:
# Display the first few rows of orders_dataset to confirm the split, reordering,
# and removal of the 'Location' column.
orders_dataset.head(1)
# Out:
#               Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156  11/8/2016  11/11/2016  Second Class    CG-12520
#
#        Customer Name   Segment        Country       City     State  \
# Row ID
# 1        Claire Gute  Consumer  United States  Henderson  Kentucky
#
#         Postal Code Region       Product ID   Category Sub-Category  \
# Row ID
# 1             42420  South  FUR-BO-10001798  Furniture    Bookcases
#
#                              Product Name   Sales  Quantity  Discount   Profit
# Row ID
# 1       Bush Somerset Collection Bookcase  261.96         2       0.0  41.9136

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">Feature Engineering 🚀🔥</p>

# %% [markdown]
# #### Calculate Discount Value and COGS 📉💰

# %%
# Calculate Discount Value:
# Multiply the 'Sales' column by -(Discount) to compute the Discount Value,
# ensuring it is negative regardless of the original sign of Discount.
orders_dataset["Discount_Value"] = orders_dataset["Sales"] * (-(orders_dataset["Discount"]))

# Calculate COGS (Cost Of Goods Sold):
# Compute COGS by subtracting the sum of 'Sales' and 'Disount_Value' from 'Profit',
# and then negating the result. This calculation represents the cost associated
# with goods sold, considering discounts and profit.
orders_dataset["COGS"] = (-((orders_dataset["Sales"] + orders_dataset["Discount_Value"]) - orders_dataset["Profit"]))

# Reorder columns to place Discount Value and COGS after Discount:
# Retrieve the current column names and find the index of 'Discount'.
# Define a new column order that inserts 'Disount_Value' and 'COGS'
# after 'Discount', moving 'Profit' to the end of the DataFrame.
columns = list(orders_dataset.columns)
discount_idx = columns.index('Discount')
new_columns_order = columns[:discount_idx + 1] + ['Discount_Value', 'COGS'] + columns[discount_idx + 1:-3] + ['Profit']

# Apply the new columns order to the DataFrame:
# Update 'orders_dataset' with the new column order to reflect the changes made.
orders_dataset = orders_dataset[new_columns_order]

# Display the first few rows of the updated dataset:
# Show the DataFrame to verify the calculations and column reordering.
orders_dataset.head()
# Out:
#               Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# Row ID
# 1       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 3       CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 4       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#           Customer Name    Segment        Country             City  \
# Row ID
# 1           Claire Gute   Consumer  United States        Henderson
# 2           Claire Gute   Consumer  United States        Henderson
# 3       Darrin Van Huff  Corporate  United States      Los Angeles
# 4        Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 5        Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#              State  ...       Product ID         Category Sub-Category  \
# ...

# %% [markdown]
# #### Calculate and Verify Profit Calculation 📊💰

# %%
# Calculate Verify_profit as the sum of 'Sales', 'COGS', and 'Discount Value'
Verify_profit = orders_dataset["Sales"] + orders_dataset["COGS"]
Verify_profit = Verify_profit + orders_dataset["Discount_Value"]

# Display the first six rows of Verify_profit to show the calculated values
Verify_profit.head(6)
# Out:
# Row ID
# 1     41.9136
# 2    219.5820
# 3      6.8714
# 4   -383.0310
# 5      2.5164
# 6     14.1694
# dtype: float64

# %%
# Display the first 6 rows of the 'Profit' column to inspect initial values
orders_dataset["Profit"].head(6)
# Out:
# Row ID
# 1     41.9136
# 2    219.5820
# 3      6.8714
# 4   -383.0310
# 5      2.5164
# 6     14.1694
# Name: Profit, dtype: float64

# %% [markdown]
# #### 📊 Reading datasets for analysis

# %%
returned_dataset = pd.read_csv("Dataset/Return.csv")  # Reading Return dataset
people_dataset = pd.read_csv("Dataset/People.csv")    # Reading People dataset
shipping_cost_dataset = pd.read_csv("Dataset/Shipping Cost.csv")  # Reading Shipping Cost dataset

# %%
# Merging returned_dataset with orders_dataset on "Order ID" using left join
orders_dataset = pd.merge(orders_dataset, returned_dataset, on="Order ID", how="left")

# Merging people_dataset with orders_dataset on "Region" using left join
orders_dataset = pd.merge(orders_dataset, people_dataset, on="Region", how="left")

# Merging shipping_cost_dataset with orders_dataset on "State" using left join
orders_dataset = pd.merge(orders_dataset, shipping_cost_dataset, on="State", how="left")

# Filling missing values in "Returned" column with "No"
orders_dataset["Returned"] = orders_dataset["Returned"].fillna("No")

# %%
orders_dataset.tail(5)
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 9988  CA-2014-110422  1/21/2014  1/23/2014    Second Class    TB-21400
# 9989  CA-2017-121258  2/26/2017  3/03/2017  Standard Class    DB-13060
# 9990  CA-2017-121258  2/26/2017  3/03/2017  Standard Class    DB-13060
# 9991  CA-2017-121258  2/26/2017  3/03/2017  Standard Class    DB-13060
# 9992  CA-2017-119914   5/4/2017  5/09/2017    Second Class    CC-12220
#
#          Customer Name   Segment        Country         City       State  ...  \
# 9988  Tom Boeckenhauer  Consumer  United States        Miami     Florida  ...
# 9989       Dave Brooks  Consumer  United States   Costa Mesa  California  ...
# 9990       Dave Brooks  Consumer  United States   Costa Mesa  California  ...
# 9991       Dave Brooks  Consumer  United States   Costa Mesa  California  ...
# 9992      Chris Cortes  Consumer  United States  Westminster  California  ...
#
# ...

# %% [markdown]
# #### Reorder Columns in DataFrame and Print First Row 🔄📊

# %%
# Assuming 'Ship Mode', 'Postal Code', 'COGS', and 'People' are columns in your DataFrame.
# Adjust the column names accordingly if they differ.

# Find the index of 'Ship Mode' and 'Postal Code' in the current columns list.
columns = list(orders_dataset.columns)
ship_mode_idx = columns.index('Ship Mode')
postal_code_idx = columns.index('Postal Code')
cogs_idx = columns.index('COGS')

# Define the new order of columns.
new_columns_order = (
    columns[:ship_mode_idx + 1] +  # Columns before 'Ship Mode'
    ['Returned'] +                 # Returned column after 'Ship Mode'
    columns[ship_mode_idx + 1:postal_code_idx + 1] +  # Columns between 'Ship Mode' and 'Postal Code'
    ['Person'] +                   # 'People' column after 'Postal Code'
    columns[postal_code_idx + 1:cogs_idx + 1] +  # Columns between 'Postal Code' and 'COGS'
    ['Shipping Cost Per Unit'] +            # 'Shipping Cost' column after 'COGS'
    columns[cogs_idx + 1:-3]       # Columns after 'Shipping Cost'
)

# Apply the new column order to the orders_dataset DataFrame.
orders_dataset = orders_dataset[new_columns_order]

# Rename 'Returned' column to 'Returned Order'.
orders_dataset = orders_dataset.rename(columns={'Returned': 'Returned Order'})

# Print the updated DataFrame to verify the changes.
orders_dataset.head(1)
# Out:
#          Order ID Order Date   Ship Date     Ship Mode Returned Order  \
# 0  CA-2016-152156  11/8/2016  11/11/2016  Second Class             No
#
#   Customer ID Customer Name   Segment        Country       City  ...  \
# 0    CG-12520   Claire Gute  Consumer  United States  Henderson  ...
#
#     Category  Sub-Category                       Product Name   Sales  \
# 0  Furniture     Bookcases  Bush Somerset Collection Bookcase  261.96
#
#   Quantity Discount Discount_Value      COGS  Shipping Cost Per Unit   Profit
# 0        2      0.0           -0.0 -220.0464                       8  41.9136
#
# [1 rows x 25 columns]

# %% [markdown]
# #### Reorder Columns and Calculate Total Shipping 📊

# %%
# Calculate Total Shipping based on Quantity and Shipping Cost Per Unit
orders_dataset["Total Shipping"] = orders_dataset["Quantity"] * orders_dataset["Shipping Cost Per Unit"]

# %%
# Calculate Total Shipping based on Quantity and Shipping Cost Per Unit
orders_dataset["Total Shipping"] = orders_dataset["Quantity"] * orders_dataset["Shipping Cost Per Unit"]

# Assuming 'Shipping Cost Per Unit' is already in your DataFrame,
# find its index and insert 'Total Shipping' after it.
columns = list(orders_dataset.columns)
shipping_cost_per_unit_idx = columns.index('Shipping Cost Per Unit')

# Define the new order of columns with 'Total Shipping' inserted after 'Shipping Cost Per Unit'
new_columns_order = (
    columns[:shipping_cost_per_unit_idx + 1] +  # Columns before 'Shipping Cost Per Unit'
    ['Total Shipping'] +                       # 'Total Shipping' column after 'Shipping Cost Per Unit'
    columns[shipping_cost_per_unit_idx + 1:-1]    # Columns after 'Shipping Cost Per Unit'
)

# Apply the new column order to the orders_dataset DataFrame
orders_dataset = orders_dataset[new_columns_order]

# Print the updated DataFrame to verify the changes.
orders_dataset.head(1)
# Out:
#          Order ID Order Date   Ship Date     Ship Mode Returned Order  \
# 0  CA-2016-152156  11/8/2016  11/11/2016  Second Class             No
#
#   Customer ID Customer Name   Segment        Country       City  ...  \
# 0    CG-12520   Claire Gute  Consumer  United States  Henderson  ...
#
#   Sub-Category                       Product Name   Sales Quantity Discount  \
# 0    Bookcases  Bush Somerset Collection Bookcase  261.96        2      0.0
#
#   Discount_Value      COGS Shipping Cost Per Unit  Total Shipping   Profit
# 0           -0.0 -220.0464                      8              16  41.9136
#
# [1 rows x 26 columns]

# %%
orders_dataset.to_csv(path_or_buf = "final_dataset.csv", index = False)

# %% [markdown]
# <p style="font-family: 'Georgia', serif; font-size: 2.5rem; color: #2c3e50; text-align: center; margin: 0; text-shadow: 2px 2px 5px rgba(0, 0, 0, 0.2); background-color: #ecf0f1; padding: 25px; border-radius: 15px; border: 5px double #8e44ad; width: 95%;">
# <b> <span style='color:#e74c3c'>Finish Preprocessing 🎉</span> <span style='color:'></span> <span style='color:#e74c3c ;font-style: italic;animation: pulse 2s infinite;'></span></b>

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">📦 Loading the Final Dataset</p>

# %%
# Read the final dataset from a CSV file named "final_dataset.csv"
final_dataset = pd.read_csv("final_dataset.csv")

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">Transformation Of Dataset 🌟</p>

# %%
# Convert all values in the 'Profit' column to their absolute values
final_dataset['Profit'] = final_dataset['Profit'].abs()

# Convert all values in the 'Discount_Value' column to their absolute values
final_dataset['Discount_Value'] = final_dataset['Discount_Value'].abs()

# Convert all values in the 'COGS' (Cost of Goods Sold) column to their absolute values
final_dataset['COGS'] = final_dataset['COGS'].abs()

# %% [markdown]
# # <p style="font-family:newtimeroman;font-size:150%;text-align:center;color:red;">Exploratory Data Analysis 📊🔍</p>

# %% [markdown]
# ### General Overview

# %% [markdown]
# #### **1. What is the total number of unique orders in the dataset?**

# %%
print(f"Total Number Of Orders : {orders_dataset["Order ID"].nunique()}")
# Out:
# Total Number Of Orders : 5009

# %% [markdown]
# #### **2. What is the date range of the orders?**

# %%
final_dataset["Order Date"] = pd.to_datetime(final_dataset["Order Date"])

oldest_date = final_dataset["Order Date"].min()
newest_date = final_dataset["Order Date"].max()

print(f"The date range of the orders is from {oldest_date.date()} to {newest_date.date()}")
# Out:
# The date range of the orders is from 2014-01-03 to 2017-12-30

# %% [markdown]
# #### **3. What are the different ship modes available?**

# %%
print(f"Different Ship Mode Avaliable : {final_dataset["Ship Mode"].unique()}")
# Out:
# Different Ship Mode Avaliable : ['Second Class' 'Standard Class' 'First Class' 'Same Day']

# %% [markdown]
# #### **4. How many orders have been returned?**

# %%
print(f"Number Of Returned Orders : {final_dataset[final_dataset["Returned Order"] == "Yes"].shape[0]}")
# Out:
# Number Of Returned Orders : 800

# %% [markdown]
# ### Customer Analysis

# %% [markdown]
# #### **5. How many unique customers are there?**

# %%
print(f"Total Number Of Customer : {final_dataset["Customer ID"].nunique()}")
# Out:
# Total Number Of Customer : 793

# %% [markdown]
# #### **6. Which customer has placed the most orders?**

# %%
# Calculate the number of orders for each customer
customer_order_counts = final_dataset.groupby(['Customer ID', 'Customer Name']).size().reset_index(name = 'Order Count')

# Find the customer with the most orders
customer_with_most_orders = customer_order_counts.loc[[customer_order_counts['Order Count'].idxmax()]]
customer_with_most_orders
# Out:
#     Customer ID  Customer Name  Order Count
# 787    WB-21850  William Brown           37

# %% [markdown]
# #### **7. What is the distribution of customers across different segments (Consumer, Corporate, Home Office)?**

# %%
# Example data (replace with your actual data)
segment_counts = final_dataset["Segment"].value_counts().sort_values(ascending = True)

# Create a bar chart
plt.figure(figsize=(8, 6))  # Create a new figure with specified size (width=10 inches, height=6 inches)

plt.barh(segment_counts.index, segment_counts.values, color=['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd'])

# Customize x-axis label
plt.xlabel('Number of Customers', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})  
# Set label for x-axis with custom font properties: fontsize=14, bold, serif font family

# Customize y-axis label
plt.ylabel('Segment', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})
# Set label for y-axis with custom font properties: fontsize=14, bold, serif font family

# Customize plot title
plt.title('Distribution of Customers Across Segments', fontdict={'fontsize': 18, 'fontweight': 'bold', 'family': 'serif'})
# Set title for the plot with custom font properties: fontsize=18, bold, serif font family

# Rotate x-axis labels for better readability and customize font properties
plt.xticks(rotation=45, fontname='serif', fontsize=12)  
# Rotate x-axis labels by 45 degrees, use serif font for tick labels, and set fontsize=12 for tick labels


# Add text annotations for each bar
for index, value in enumerate(segment_counts.values):
    plt.text(value, index, str(f" {value}"), va='center', ha='left', fontsize=12, fontweight='bold')
# 'plt.text' adds text to the plot
# 'value' is the count of each segment
# 'index' is the position of the segment on the y-axis
# 'str(value)' converts the count to a string to display as text
# 'va' and 'ha' are vertical and horizontal alignment properties
# 'fontsize' sets the font size for the text
# 'fontweight' sets the font weight for the text

# Display the chart
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()  # Display the plot

# %% [markdown]
# ### Geographic Analysis

# %% [markdown]
# **8. Which cities have the highest number of orders?**

# %%
# Example data (replace with your actual data)
cities_counts = final_dataset["City"].value_counts().head(10).sort_values(ascending = True)

# Create a bar chart
plt.figure(figsize=(10, 6))  # Create a new figure with specified size (width=10 inches, height=6 inches)
plt.barh(cities_counts.index, cities_counts.values, color = ['#ff0000', '#00ff00', '#0000ff', '#ffff00', '#ff00ff'])  # Create a bar chart with segments on x-axis and counts on y-axis, using skyblue color for bars

# Customize y-axis label
plt.ylabel('Cities', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})  
# Set label for y-axis with custom font properties: fontsize=14, bold, serif font family

# Customize x-axis label
plt.xlabel('Number of Orders', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})
# Set label for x-axis with custom font properties: fontsize=14, bold, serif font family

# Customize plot title
plt.title('Cities with the Highest Number of Orders', fontdict={'fontsize': 18, 'fontweight': 'bold', 'family': 'serif'})
# Set title for the plot with custom font properties: fontsize=18, bold, serif font family

# Rotate x-axis labels for better readability and customize font properties
plt.xticks(rotation=45, fontname='serif', fontsize=12)  
# Rotate x-axis labels by 45 degrees, use serif font for tick labels, and set fontsize=12 for tick labels


# Text properties
# Add text annotations for each bar
for index, value in enumerate(cities_counts.values):
    plt.text(value, index, str(f" {value}"), va='center', ha='left', fontsize=12, fontweight='bold')
# 'plt.text' adds text to the plot
# 'value' is the count of each segment
# 'index' is the position of the segment on the y-axis
# 'str(value)' converts the count to a string to display as text
# 'va' and 'ha' are vertical and horizontal alignment properties
# 'fontsize' sets the font size for the text
# 'fontweight' sets the font weight for the text

# Display the chart
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()  # Display the plot

# %% [markdown]
# **9. How are orders distributed across different states?**

# %%
# Example data (replace with your actual data)
states_counts = final_dataset["State"].value_counts().head(10).sort_values(ascending = True)

# Create a bar chart
plt.figure(figsize=(10, 6))  # Create a new figure with specified size (width=10 inches, height=6 inches)
plt.barh(states_counts.index, states_counts.values, color='skyblue')  # Create a bar chart with segments on x-axis and counts on y-axis, using skyblue color for bars

# Customize x-axis label
plt.xlabel('Number of Customers', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})  
# Set label for x-axis with custom font properties: fontsize=14, bold, serif font family

# Customize y-axis label
plt.ylabel('Segment', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})
# Set label for y-axis with custom font properties: fontsize=14, bold, serif font family

# Customize plot title
plt.title('Distribution of Customers Across Segments', fontdict={'fontsize': 18, 'fontweight': 'bold', 'family': 'serif'})
# Set title for the plot with custom font properties: fontsize=18, bold, serif font family

# Rotate x-axis labels for better readability and customize font properties
plt.xticks(rotation=45, fontname='serif', fontsize=12)  
# Rotate x-axis labels by 45 degrees, use serif font for tick labels, and set fontsize=12 for tick labels

# Text properties
# Add text annotations for each bar
for index, value in enumerate(states_counts.values):
    plt.text(value, index, str(f" {value}"), va='center', ha='left', fontsize=12, fontweight='bold')
# 'plt.text' adds text to the plot
# 'value' is the count of each segment
# 'index' is the position of the segment on the y-axis
# 'str(value)' converts the count to a string to display as text
# 'va' and 'ha' are vertical and horizontal alignment properties
# 'fontsize' sets the font size for the text
# 'fontweight' sets the font weight for the text

# Display the grid
plt.grid(True, axis='x')  # Display grid lines on the plot
    
# Display the chart
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()  # Display the plot

# %% [markdown]
# **10. Which region has the highest sales?**

# %%
# Group by region and sum the sales
region_sales = final_dataset.groupby("Region")["Sales"].sum()

# Sort the regions by sales in descending order to find the region with the highest sales
region_sales_sorted = region_sales.sort_values(ascending=False)

# Create a figure with two subplots: one for the pie chart and one for the bar chart
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# Pie chart on the left subplot (ax1)
ax1.pie(region_sales_sorted,  # Data for the pie chart (sales by region)
        labels=region_sales_sorted.index,  # Labels for each slice (region names)
        autopct='%1.1f%%',  # Format for displaying percentages
        startangle=140,  # Start angle for the first slice (140 degrees)
        colors=colors,  # Custom colors for each slice
        explode=[0.1 if i == region_sales_sorted.idxmax() else 0 for i in region_sales_sorted.index])  # "Explode" the slice with the highest sales

ax1.set_title('Sales Distribution Across Regions', fontsize=16, fontweight='bold')  # Set title for the pie chart

# Bar chart on the right subplot (ax2)
ax2.bar(region_sales_sorted.index, region_sales_sorted.values, color=colors)  # Data for the bar chart (sales by region)
ax2.set_xlabel('Region', fontsize=14, fontweight='bold')  # Set label for x-axis
ax2.set_ylabel('Total Sales ($)', fontsize=14, fontweight='bold')  # Set label for y-axis
ax2.set_title('Total Sales by Region', fontsize=16, fontweight='bold')  # Set title for the bar chart
ax2.grid(True, axis='y')  # Display grid lines along the y-axis

# Rotate x-axis labels for better readability
ax2.tick_params(axis='x', rotation=45)  # Rotate x-axis labels by 45 degrees

# Annotate each bar with its value
for bar in ax2.patches:
    yval = bar.get_height()  # Retrieve the height of each bar
    ax2.annotate(format(yval, ','),  # Format the value with commas
                 (bar.get_x() + bar.get_width() / 2, yval),  # Position of the annotation (center of each bar)
                 va='bottom', ha='center',  # Vertical and horizontal alignment of the text
                 xytext=(0, 5), textcoords='offset points',  # Offset and coordinate system for positioning the text
                 fontsize=10, fontweight='bold')  # Font size and weight for the annotation text

plt.tight_layout()  # Adjust layout to prevent overlapping of labels and titles

plt.show()  # Display the plot

# %% [markdown]
# ### Product Analysis

# %% [markdown]
# **12. How many unique products are there?**

# %%
print(f"There are ({final_dataset["Product Name"].nunique()}) unique products.")
# Out:
# There are (1850) unique products.

# %% [markdown]
# **13. Which product category generates the most revenue?**

# %%
# Example data (replace with your actual data)
categories_counts = final_dataset.groupby("Category")["Sales"].sum().sort_values(ascending = False)

# Create a bar chart
plt.figure(figsize=(10, 6))  # Create a new figure with specified size (width=10 inches, height=6 inches)
bars = plt.bar(categories_counts.index, categories_counts.values, color='skyblue')  # Create a bar chart with segments on x-axis and counts on y-axis, using skyblue color for bars

# Customize x-axis label
plt.xlabel('Categories', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})  
# Set label for x-axis with custom font properties: fontsize=14, bold, serif font family

# Customize y-axis label
plt.ylabel('Sales ($)', fontdict={'fontsize': 14, 'fontweight': 'bold', 'family': 'serif'})
# Set label for y-axis with custom font properties: fontsize=14, bold, serif font family

# Customize plot title
plt.title('Sales by Product Category', fontdict={'fontsize': 18, 'fontweight': 'bold', 'family': 'serif'})
# Set title for the plot with custom font properties: fontsize=18, bold, serif font family

# Rotate x-axis labels for better readability and customize font properties
plt.xticks(rotation=45, fontname='serif', fontsize=12)  
# Rotate x-axis labels by 45 degrees, use serif font for tick labels, and set fontsize=12 for tick labels

# Display the grid
plt.grid(True, axis='y')  # Display grid lines on the plot

# Annotate each bar with its value
for bar in bars:
    yval = bar.get_height()  # Retrieve the height of the bar
    plt.text(bar.get_x() + bar.get_width()/2, yval, format(yval, ','),  # Position and format of the text
             va='bottom', ha='center', fontsize=10, fontweight='bold', family='serif')  # Text properties
    
# Display the chart
plt.tight_layout()  # Adjust layout to prevent clipping of labels
plt.show()  # Display the plot

# %% [markdown]
#  **14. Which sub-category of products is the most popular?**

# %%
sub_category_popular = final_dataset["Sub-Category"].value_counts().idxmax()
num_orders = final_dataset["Sub-Category"].value_counts().max()
print(f"The most popular sub-category is '{sub_category_popular}' with ({num_orders}) orders.")
# Out:
# The most popular sub-category is 'Binders' with (1523) orders.

# %% [markdown]
# **15. Which individual product has the highest sales?**

# %%
product_sales = final_dataset.groupby("Product Name")["Sales"].sum()
highest_sales_product = product_sales.idxmax()
highest_sales_amount = product_sales.max()
print(f"The individual product with the highest sales is '{highest_sales_product}' with total sales of (${highest_sales_amount:.2f}).")
# Out:
# The individual product with the highest sales is 'Canon imageCLASS 2200 Advanced Copier' with total sales of ($61599.82).

# %% [markdown]
# ### Sales and Profit Analysis

# %% [markdown]
# **16. What is the total sales amount?**

# %%
total_sales = final_dataset["Sales"].sum()
print(f"The total sales amount is ($ {total_sales:.2f}).")
# Out:
# The total sales amount is ($ 2296919.49).

# %% [markdown]
# **17. What is the average sales per order?**

# %%
average_sales_per_order = final_dataset["Sales"].mean()
print(f"The average sales per order is (${average_sales_per_order:.2f}).")
# Out:
# The average sales per order is ($229.85).

# %% [markdown]
# **18. What is the total profit generated?**

# %%
total_profit = final_dataset["Profit"].sum()
print(f"The total profit generated is (${total_profit:.2f}).")
# Out:
# The total profit generated is ($598647.53).

# %% [markdown]
# **19. What is the average profit per order?**

# %%
average_profit_per_order = final_dataset["Profit"].mean()
print(f"The average profit per order is (${average_profit_per_order:.2f}).")
# Out:
# The average profit per order is ($59.91).

# %% [markdown]
# **20. How does profit vary across different regions?**

# %%
# Calculate total profit by region and sort in descending order
profit_by_regions = final_dataset.groupby("Region")["Profit"].sum().sort_values(ascending=False)

# Create a figure with two subplots: one for the pie chart and one for the bar chart
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# Pie chart on the left subplot (ax1)
ax1.pie(profit_by_regions,  # Data for the pie chart (profit by region)
        labels=profit_by_regions.index,  # Labels for each slice (region names)
        autopct='%1.1f%%',  # Format for displaying percentages
        startangle=140,  # Start angle for the first slice (140 degrees)
        colors=colors,  # Custom colors for each slice
        explode=[0.1 if i == profit_by_regions.idxmax() else 0 for i in profit_by_regions.index])  # "Explode" the slice with the highest profit

ax1.set_title('Profit Distribution Across Regions', fontsize=16, fontweight='bold')  # Set title for the pie chart

# Bar chart on the right subplot (ax2)
ax2.bar(profit_by_regions.index, profit_by_regions.values, color=colors)  # Data for the bar chart (profit by region)
ax2.set_xlabel('Region', fontsize=14, fontweight='bold')  # Set label for x-axis
ax2.set_ylabel('Total Profit ($)', fontsize=14, fontweight='bold')  # Set label for y-axis
ax2.set_title('Total Profit by Region', fontsize=16, fontweight='bold')  # Set title for the bar chart
ax2.grid(True, axis='y')  # Display grid lines along the y-axis

# Rotate x-axis labels for better readability
ax2.tick_params(axis='x', rotation=45)  # Rotate x-axis labels by 45 degrees

# Annotate each bar with its value
for bar in ax2.patches:
    yval = bar.get_height()  # Retrieve the height of each bar
    ax2.annotate(format(yval, ','),  # Format the value with commas
                 (bar.get_x() + bar.get_width() / 2, yval),  # Position of the annotation (center of each bar)
                 va='bottom', ha='center',  # Vertical and horizontal alignment of the text
                 xytext=(0, 5), textcoords='offset points',  # Offset and coordinate system for positioning the text
                 fontsize=10, fontweight='bold')  # Font size and weight for the annotation text

plt.tight_layout()  # Adjust layout to prevent overlapping of labels and titles

plt.show()  # Display the plot

# %% [markdown]
# ### Shipping Analysis

# %% [markdown]
# **21. What is the average shipping cost per order?**

# %%
# Assuming 'final_dataset' is your DataFrame
# Calculate the average shipping cost per order
average_shipping_cost = final_dataset["Shipping Cost Per Unit"].mean()

print(f"The average shipping cost per order is ${average_shipping_cost:.2f}")
# Out:
# The average shipping cost per order is $5.94

# %% [markdown]
# **22. Which shipping mode is the most cost-effective?**

# %%
# Assuming 'final_dataset' is your DataFrame
# Calculate the average shipping cost per unit for each shipping mode
avg_shipping_cost_per_mode = final_dataset.groupby("Ship Mode")["Shipping Cost Per Unit"].mean()

# Find the most cost-effective shipping mode (the one with the lowest average shipping cost)
most_cost_effective_mode = avg_shipping_cost_per_mode.idxmin()
lowest_avg_cost = avg_shipping_cost_per_mode.min()

print("Average shipping cost per shipping mode:")
print(avg_shipping_cost_per_mode)
print(f"\nThe most cost-effective shipping mode is '{most_cost_effective_mode}' with an average cost of ${lowest_avg_cost:.2f}")
# Out:
# Average shipping cost per shipping mode:
# Ship Mode
# First Class       6.031860
# Same Day          6.130755
# Second Class      5.974807
# Standard Class    5.882688
# Name: Shipping Cost Per Unit, dtype: float64
#
# The most cost-effective shipping mode is 'Standard Class' with an average cost of $5.88

# %% [markdown]
# **23. How does the shipping cost vary by region?**

# %%
shipping_cost_region = final_dataset.groupby("Region")["Total Shipping"].sum().sort_values(ascending = False)

# Create a figure with two subplots: one for the pie chart and one for the bar chart
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 8))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

# Pie chart on the left subplot (ax1)
ax1.pie(shipping_cost_region,  # Data for the pie chart (profit by region)
        labels=shipping_cost_region.index,  # Labels for each slice (region names)
        autopct='%1.1f%%',  # Format for displaying percentages
        startangle=140,  # Start angle for the first slice (140 degrees)
        colors=colors,  # Custom colors for each slice
        explode=[0.1 if i == profit_by_regions.idxmax() else 0 for i in profit_by_regions.index])  # "Explode" the slice with the highest profit

ax1.set_title('Profit Distribution Across Regions', fontsize=16, fontweight='bold')  # Set title for the pie chart

# Bar chart on the right subplot (ax2)
ax2.bar(shipping_cost_region.index, shipping_cost_region.values, color=colors)  # Data for the bar chart (profit by region)
ax2.set_xlabel('Region', fontsize=14, fontweight='bold')  # Set label for x-axis
ax2.set_ylabel('Total Profit ($)', fontsize=14, fontweight='bold')  # Set label for y-axis
ax2.set_title('Total Profit by Region', fontsize=16, fontweight='bold')  # Set title for the bar chart
ax2.grid(True, axis='y')  # Display grid lines along the y-axis

# Rotate x-axis labels for better readability
ax2.tick_params(axis='x', rotation=45)  # Rotate x-axis labels by 45 degrees

# Annotate each bar with its value
for bar in ax2.patches:
    yval = bar.get_height()  # Retrieve the height of each bar
    ax2.annotate(format(yval, ','),  # Format the value with commas
                 (bar.get_x() + bar.get_width() / 2, yval),  # Position of the annotation (center of each bar)
                 va='bottom', ha='center',  # Vertical and horizontal alignment of the text
                 xytext=(0, 5), textcoords='offset points',  # Offset and coordinate system for positioning the text
                 fontsize=10, fontweight='bold')  # Font size and weight for the annotation text

plt.tight_layout()  # Adjust layout to prevent overlapping of labels and titles

plt.show()  # Display the plot

# %% [markdown]
# **24. What is the correlation between shipping cost and profit?**

# %%
# Assuming 'final_dataset' is your DataFrame
# Calculate the correlation between shipping cost per unit and profit
correlation = final_dataset["Shipping Cost Per Unit"].corr(final_dataset["Profit"])

print(f"The correlation between shipping cost and profit is {correlation:.2f}")
# Out:
# The correlation between shipping cost and profit is -0.02

# %% [markdown]
# **The Pearson correlation coefficient ranges from -1 to 1:**
#
# * A value close to 1 indicates a strong positive correlation.
# * **A value close to -1 indicates a strong negative correlation.**
# * A value close to 0 indicates little to no correlation.

# %% [markdown]
# ### Time Series Analysis

# %% [markdown]
# **25. How do sales, Discount_Value, Profit, COGS and Total Shipping trends change over time (monthly)?**

# %%
# Assuming 'final_dataset' is your DataFrame and 'Order Date' is in datetime format
final_dataset['Order Date'] = pd.to_datetime(final_dataset['Order Date'])

# Aggregate data by month
monthly_data = final_dataset.groupby(pd.Grouper(key='Order Date', freq='ME')).agg({
    'Sales': 'sum',  # Calculate total sales for each monthE
    'Discount_Value': 'sum',  # Calculate total discount value for each month
    'Profit': 'sum',  # Calculate total profit for each month
    'COGS': 'sum',  # Calculate total cost of goods sold for each month
    'Total Shipping': 'sum'  # Calculate total shipping cost for each month
}).reset_index()  # Add 'Order Date' back as a column in the result

# Create a figure and axes with a grid layout (2 rows, 3 columns)
fig, axs = plt.subplots(2, 3, figsize=(18, 12))

# Plot Sales
axs[0, 0].plot(monthly_data['Order Date'], monthly_data['Sales'], marker='o', linestyle='-', color='blue')
axs[0, 0].set_ylabel('Sales ($)', fontsize=12)
axs[0, 0].set_title('Sales', fontsize=14, fontweight='bold')

# Plot Discount_Value
axs[0, 1].plot(monthly_data['Order Date'], monthly_data['Discount_Value'], marker='o', linestyle='-', color='orange')
axs[0, 1].set_ylabel('Discount Value ($)', fontsize=12)
axs[0, 1].set_title('Discount Value', fontsize=14, fontweight='bold')

# Plot Profit
axs[0, 2].plot(monthly_data['Order Date'], monthly_data['Profit'], marker='o', linestyle='-', color='green')
axs[0, 2].set_ylabel('Profit ($)', fontsize=12)
axs[0, 2].set_title('Profit', fontsize=14, fontweight='bold')

# Plot COGS
axs[1, 0].plot(monthly_data['Order Date'], monthly_data['COGS'], marker='o', linestyle='-', color='red')
axs[1, 0].set_ylabel('COGS ($)', fontsize=12)
axs[1, 0].set_title('COGS', fontsize=14, fontweight='bold')

# Plot Total Shipping
axs[1, 1].plot(monthly_data['Order Date'], monthly_data['Total Shipping'], marker='o', linestyle='-', color='purple')
axs[1, 1].set_ylabel('Total Shipping ($)', fontsize=12)
axs[1, 1].set_title('Total Shipping', fontsize=14, fontweight='bold')

# Remove the empty subplot (axs[1, 2])
fig.delaxes(axs[1, 2])

# Customize x-axis labels rotation for better readability
for ax in axs.flat:
    ax.tick_params(axis='x', rotation=45)

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# **26. How do sales, Discount_Value, Profit, COGS and Total Shipping trends change over time (yearly)?**

# %%
# Assuming 'final_dataset' is your DataFrame and 'Order Date' is in datetime format
final_dataset['Order Year'] = final_dataset['Order Date'].dt.year

# Aggregate data by year
yearly_data = final_dataset.groupby('Order Year').agg({
    'Sales': 'sum',
    'Discount_Value': 'sum',
    'Profit': 'sum',
    'COGS': 'sum',
    'Total Shipping': 'sum'
}).reset_index()

# Create a figure with subplots
fig, axs = plt.subplots(2, 3, figsize=(20, 6))

# Plot each metric in a separate subplot for better visualization
# Plot for Sales metric
axs[0, 0].plot(yearly_data['Order Year'], yearly_data['Sales'], marker='o', linestyle='-', color='blue')
axs[0, 0].set_title('Sales')  # Set title for this subplot
axs[0, 0].set_xlabel('Year')  # Set label for x-axis
axs[0, 0].set_ylabel('Amount ($)')  # Set label for y-axis

# Plot for Discount Value metric
axs[0, 1].plot(yearly_data['Order Year'], yearly_data['Discount_Value'], marker='o', linestyle='-', color='orange')
axs[0, 1].set_title('Discount Value')  # Set title for this subplot
axs[0, 1].set_xlabel('Year')  # Set label for x-axis

# Plot for Profit metric
axs[0, 2].plot(yearly_data['Order Year'], yearly_data['Profit'], marker='o', linestyle='-', color='green')
axs[0, 2].set_title('Profit')  # Set title for this subplot
axs[0, 2].set_xlabel('Year')  # Set label for x-axis

# Plot for COGS (Cost of Goods Sold) metric
axs[1, 0].plot(yearly_data['Order Year'], yearly_data['COGS'], marker='o', linestyle='-', color='red')
axs[1, 0].set_title('COGS')  # Set title for this subplot
axs[1, 0].set_xlabel('Year')  # Set label for x-axis

# Plot for Total Shipping metric
axs[1, 1].plot(yearly_data['Order Year'], yearly_data['Total Shipping'], marker='o', linestyle='-', color='purple')
axs[1, 1].set_title('Total Shipping')  # Set title for this subplot
axs[1, 1].set_xlabel('Year')  # Set label for x-axis

# Remove the empty subplot (axs[1, 2])
fig.delaxes(axs[1, 2])

# Adjust layout to prevent overlap
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# <p style="font-family: 'Georgia', serif; font-size: 2.5rem; color: #2c3e50; text-align: center; margin: 0; text-shadow: 2px 2px 5px rgba(0, 0, 0, 0.2); background-color: #ecf0f1; padding: 25px; border-radius: 15px; border: 5px double #8e44ad; width: 95%;">
# <b> <span style='color:#e74c3c'>Finish Analysis Of Data</span> <span style='color:'></span> <span style='color:#e74c3c ;font-style: italic;animation: pulse 2s infinite;'></span></b>
